# %%
# Import dependencies
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from datetime import datetime, timedelta

# %%
# Set pandas options
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# Import raw dataframes
path = os.path.join(os.getcwd(), 'data')

train_df_raw = pd.read_csv(os.path.join(path, 'train.csv'))
weather_train_raw = pd.read_csv(os.path.join(path, 'weather_train.csv'))
weather_test_raw = pd.read_csv(os.path.join(path, 'weather_test.csv'))
building_raw = pd.read_csv(os.path.join(path, 'building_metadata.csv'))

# %%
train_df = train_df_raw.copy()
train_df
# Out:
#           building_id  meter            timestamp  meter_reading
# 0                   0      0  2016-01-01 00:00:00          0.000
# 1                   1      0  2016-01-01 00:00:00          0.000
# 2                   2      0  2016-01-01 00:00:00          0.000
# 3                   3      0  2016-01-01 00:00:00          0.000
# 4                   4      0  2016-01-01 00:00:00          0.000
# ...               ...    ...                  ...            ...
# 20216095         1444      0  2016-12-31 23:00:00          8.750
# 20216096         1445      0  2016-12-31 23:00:00          4.825
# 20216097         1446      0  2016-12-31 23:00:00          0.000
# 20216098         1447      0  2016-12-31 23:00:00        159.575
# 20216099         1448      0  2016-12-31 23:00:00          2.850
#
# [20216100 rows x 4 columns]

# %%
weather_train = weather_train_raw.copy()
weather_train
# Out:
#         site_id            timestamp  air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  wind_speed
# 0             0  2016-01-01 00:00:00             25.0             6.0             20.0                NaN              1019.7             0.0         0.0
# 1             0  2016-01-01 01:00:00             24.4             NaN             21.1               -1.0              1020.2            70.0         1.5
# 2             0  2016-01-01 02:00:00             22.8             2.0             21.1                0.0              1020.2             0.0         0.0
# 3             0  2016-01-01 03:00:00             21.1             2.0             20.6                0.0              1020.1             0.0         0.0
# 4             0  2016-01-01 04:00:00             20.0             2.0             20.0               -1.0              1020.0           250.0         2.6
# ...         ...                  ...              ...             ...              ...                ...                 ...             ...         ...
# 139768       15  2016-12-31 19:00:00              3.0             NaN             -8.0                NaN                 NaN           180.0         5.7
# 139769       15  2016-12-31 20:00:00              2.8             2.0             -8.9                NaN              1007.4           180.0         7.7
# 139770       15  2016-12-31 21:00:00              2.8             NaN             -7.2                NaN              1007.5           180.0         5.1
# 139771       15  2016-12-31 22:00:00              2.2             NaN             -6.7                NaN              1008.0           170.0         4.6
# 139772       15  2016-12-31 23:00:00              1.7             NaN             -5.6               -1.0              1008.5           180.0         8.8
#
# [139773 rows x 9 columns]

# %%
weather_test = weather_test_raw.copy()
weather_test
# Out:
#         site_id            timestamp  air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  wind_speed
# 0             0  2017-01-01 00:00:00             17.8             4.0             11.7                NaN              1021.4           100.0         3.6
# 1             0  2017-01-01 01:00:00             17.8             2.0             12.8                0.0              1022.0           130.0         3.1
# 2             0  2017-01-01 02:00:00             16.1             0.0             12.8                0.0              1021.9           140.0         3.1
# 3             0  2017-01-01 03:00:00             17.2             0.0             13.3                0.0              1022.2           140.0         3.1
# 4             0  2017-01-01 04:00:00             16.7             2.0             13.3                0.0              1022.3           130.0         2.6
# ...         ...                  ...              ...             ...              ...                ...                 ...             ...         ...
# 277238       15  2018-12-31 19:00:00              3.3             NaN              1.7                NaN              1018.3           150.0         7.7
# 277239       15  2018-12-31 20:00:00              2.8             NaN              1.1                NaN              1017.8           140.0         5.1
# 277240       15  2018-12-31 21:00:00              2.8             NaN              1.7               -1.0              1017.2           140.0         6.2
# 277241       15  2018-12-31 22:00:00              2.8             NaN              2.2                8.0              1016.1           140.0         5.1
# 277242       15  2018-12-31 23:00:00              3.3             NaN              2.2               20.0              1014.7           140.0         5.1
#
# [277243 rows x 9 columns]

# %%
building_df = building_raw.copy()
building_df
# Out:
#       site_id  building_id                    primary_use  square_feet  year_built  floor_count
# 0           0            0                      Education         7432      2008.0          NaN
# 1           0            1                      Education         2720      2004.0          NaN
# 2           0            2                      Education         5376      1991.0          NaN
# 3           0            3                      Education        23685      2002.0          NaN
# 4           0            4                      Education       116607      1975.0          NaN
# ...       ...          ...                            ...          ...         ...          ...
# 1444       15         1444  Entertainment/public assembly        19619      1914.0          NaN
# 1445       15         1445                      Education         4298         NaN          NaN
# 1446       15         1446  Entertainment/public assembly        11265      1997.0          NaN
# 1447       15         1447            Lodging/residential        29775      2001.0          NaN
# 1448       15         1448                         Office        92271      2001.0          NaN
#
# [1449 rows x 6 columns]

# %%
# Merge datasets
train_merged = train_df.merge(building_df, on='building_id', how='left')
train_merged = train_merged.merge(weather_train, on=['site_id', 'timestamp'], how='left')

# %%
train_merged
# Out:
#           building_id  meter            timestamp  meter_reading  site_id                    primary_use  square_feet  year_built  floor_count  air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  wind_speed
# 0                   0      0  2016-01-01 00:00:00          0.000        0                      Education         7432      2008.0          NaN             25.0             6.0             20.0                NaN              1019.7             0.0         0.0
# 1                   1      0  2016-01-01 00:00:00          0.000        0                      Education         2720      2004.0          NaN             25.0             6.0             20.0                NaN              1019.7             0.0         0.0
# 2                   2      0  2016-01-01 00:00:00          0.000        0                      Education         5376      1991.0          NaN             25.0             6.0             20.0                NaN              1019.7             0.0         0.0
# 3                   3      0  2016-01-01 00:00:00          0.000        0                      Education        23685      2002.0          NaN             25.0             6.0             20.0                NaN              1019.7             0.0         0.0
# 4                   4      0  2016-01-01 00:00:00          0.000        0                      Education       116607      1975.0          NaN             25.0             6.0             20.0                NaN              1019.7             0.0         0.0
# ...               ...    ...                  ...            ...      ...                            ...          ...         ...          ...              ...             ...              ...                ...                 ...             ...         ...
# 20216095         1444      0  2016-12-31 23:00:00          8.750       15  Entertainment/public assembly        19619      1914.0          NaN              1.7             NaN             -5.6               -1.0              1008.5           180.0         8.8
# 20216096         1445      0  2016-12-31 23:00:00          4.825       15                      Education         4298         NaN          NaN              1.7             NaN             -5.6               -1.0              1008.5           180.0         8.8
# 20216097         1446      0  2016-12-31 23:00:00          0.000       15  Entertainment/public assembly        11265      1997.0          NaN              1.7             NaN             -5.6               -1.0              1008.5           180.0         8.8
# 20216098         1447      0  2016-12-31 23:00:00        159.575       15            Lodging/residential        29775      2001.0          NaN              1.7             NaN             -5.6               -1.0              1008.5           180.0         8.8
# 20216099         1448      0  2016-12-31 23:00:00          2.850       15                         Office        92271      2001.0          NaN              1.7             NaN             -5.6               -1.0              1008.5           180.0         8.8
#
# [20216100 rows x 16 columns]

# %%
train_merged.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20216100 entries, 0 to 20216099
# Data columns (total 16 columns):
#  #   Column              Non-Null Count     Dtype
# ---  ------              --------------     -----
#  0   building_id         20216100 non-null  int64
#  1   meter               20216100 non-null  int64
#  2   timestamp           20216100 non-null  datetime64[ns]
#  3   meter_reading       20216100 non-null  float64
#  4   site_id             20216100 non-null  int64
#  5   primary_use         20216100 non-null  int32
#  6   square_feet         20216100 non-null  int64
#  7   year_built          8088455 non-null   float64
#  8   floor_count         3506933 non-null   float64
#  9   air_temperature     20119442 non-null  float64
#  10  cloud_coverage      11390735 non-null  float64
#  11  dew_temperature     20115960 non-null  float64
#  12  precip_depth_1_hr   16467077 non-null  float64
#  13  sea_level_pressure  18984431 non-null  float64
#  14  wind_direction      18767052 non-null  float64
#  15  wind_speed          20072424 non-null  float64
# dtypes: datetime64[ns](1), float64(10), int32(1), int64(4)
# memory usage: 2.5 GB

# %%
# Encoding primary_use
primary_use_map = {'Education': 1, 'Office': 2, 'Entertainment/public assembly': 3, 'Lodging/residential': 4,
                   'Public services': 5, 'Healthcare': 6, 'Other': 7, 'Parking': 8, 'Manufacturing/industrial': 9,
                   'Food sales and service': 10, 'Retail': 11, 'Warehouse/storage': 12, 'Services': 13, 
                   'Technology/science': 14, 'Utility': 15, 'Religious worship': 16}

train_merged['primary_use'] = train_merged['primary_use'].map(primary_use_map).astype(np.int64)

# %%
# Convert timestamp to datetime
train_merged['timestamp'] = pd.to_datetime(train_merged['timestamp'], infer_datetime_format=True)

# %%
# Fill null, and convert year_built
train_merged['year_built'].fillna(0, inplace=True)
train_merged['year_built'] = train_merged['year_built'].astype(np.int64)

# %%
train_merged.isnull().sum()
# Out:
# building_id                  0
# meter                        0
# timestamp                    0
# meter_reading                0
# site_id                      0
# primary_use                  0
# square_feet                  0
# year_built                   0
# floor_count           16709167
# air_temperature          96658
# cloud_coverage         8825365
# dew_temperature         100140
# precip_depth_1_hr      3749023
# sea_level_pressure     1231669
# wind_direction         1449048
# wind_speed              143676
# dtype: int64

# %%
train_merged['meter'].unique()
# Out:
# array([0, 3, 1, 2], dtype=int64)

# %%
submission = pd.read_csv(os.path.join(path, 'sample_submission.csv'))
submission
# Out:
#             row_id  meter_reading
# 0                0              0
# 1                1              0
# 2                2              0
# 3                3              0
# 4                4              0
# ...            ...            ...
# 41697595  41697595              0
# 41697596  41697596              0
# 41697597  41697597              0
# 41697598  41697598              0
# 41697599  41697599              0
#
# [41697600 rows x 2 columns]

# %%
test_df = pd.read_csv(os.path.join(path, 'test.csv'))
test_df
# Out:
#             row_id  building_id  meter            timestamp
# 0                0            0      0  2017-01-01 00:00:00
# 1                1            1      0  2017-01-01 00:00:00
# 2                2            2      0  2017-01-01 00:00:00
# 3                3            3      0  2017-01-01 00:00:00
# 4                4            4      0  2017-01-01 00:00:00
# ...            ...          ...    ...                  ...
# 41697595  41697595         1444      0  2018-05-09 07:00:00
# 41697596  41697596         1445      0  2018-05-09 07:00:00
# 41697597  41697597         1446      0  2018-05-09 07:00:00
# 41697598  41697598         1447      0  2018-05-09 07:00:00
# 41697599  41697599         1448      0  2018-05-09 07:00:00
#
# [41697600 rows x 4 columns]

# %%
ax = plt.subplot(111)
ax.bar(train_merged['timestamp'].values, train_merged['meter_reading'], width=10)
ax.xaxis_date()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [41], in <cell line: 2>()
#       1 ax = plt.subplot(111)
# ----> 2 ax.bar(train_merged['timestamp'].values, train_merged['meter_reading'], width=10)
#       3 ax.xaxis_date()
#       5 plt.show()
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\axes\_axes.py:2409, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2407     elif orientation == 'horizontal':
#    2408         r.sticky_edges.x.append(l)
# -> 2409     self.add_patch(r)
#    2410     patches.append(r)
#    2412 if xerr is not None or yerr is not None:
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\axes\_base.py:2362, in _AxesBase.add_patch(self, p)
#    2360 self._set_artist_props(p)
#    2361 if p.get_clip_path() is None:
# -> 2362     p.set_clip_path(self.patch)
#    2363 self._update_patch_limits(p)
#    2364 self._children.append(p)
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\artist.py:790, in Artist.set_clip_path(self, path, transform)
#     787 if transform is None:
#     788     if isinstance(path, Rectangle):
#     789         self.clipbox = TransformedBbox(Bbox.unit(),
# --> 790                                        path.get_transform())
#     791         self._clippath = None
#     792         success = True
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\patches.py:278, in Patch.get_transform(self)
#     276 def get_transform(self):
#     277     """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 278     return self.get_patch_transform() + artist.Artist.get_transform(self)
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\patches.py:760, in Rectangle.get_patch_transform(self)
#     753 def get_patch_transform(self):
#     754     # Note: This cannot be called until after this has been added to
#     755     # an Axes, otherwise unit conversion will fail. This makes it very
#     756     # important to call the accessor method and not directly access the
#     757     # transformation member variable.
#     758     bbox = self.get_bbox()
#     759     return (transforms.BboxTransformTo(bbox)
# --> 760             + transforms.Affine2D().rotate_deg_around(
#     761                 bbox.x0, bbox.y0, self.angle))
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\transforms.py:1913, in Affine2D.__init__(self, matrix, **kwargs)
#    1910 super().__init__(**kwargs)
#    1911 if matrix is None:
#    1912     # A bit faster than np.identity(3).
# -> 1913     matrix = IdentityTransform._mtx.copy()
#    1914 self._mtx = matrix.copy()
#    1915 self._invalid = 0
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x0000017348087550> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib_inline\backend_inline.py:121, in flush_figures()
#     118 if InlineBackend.instance().close_figures:
#     119     # ignore the tracking, just draw and close all figures
#     120     try:
# --> 121         return show(True)
#     122     except Exception as e:
#     123         # safely show traceback if in IPython, else raise
#     124         ip = get_ipython()
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib_inline\backend_inline.py:41, in show(close, block)
#      39 try:
#      40     for figure_manager in Gcf.get_all_fig_managers():
# ---> 41         display(
#      42             figure_manager.canvas.figure,
#      43             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44         )
#      45 finally:
#      46     show._to_draw = []
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\IPython\core\formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\IPython\core\formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\IPython\core\formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\IPython\core\pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\backend_bases.py:2299, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
# -> 2299         bbox_inches = self.figure.get_tightbbox(
#    2300             renderer, bbox_extra_artists=bbox_extra_artists)
#    2301         if pad_inches is None:
#    2302             pad_inches = rcParams['savefig.pad_inches']
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\figure.py:1684, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1681     artists = bbox_extra_artists
#    1683 for a in artists:
# -> 1684     bbox = a.get_tightbbox(renderer)
#    1685     if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    1686         bb.append(bbox)
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\artist.py:355, in Artist.get_tightbbox(self, renderer)
#     340 def get_tightbbox(self, renderer):
#     341     """
#     342     Like `.Artist.get_window_extent`, but includes any clipping.
#     343
#    (...)
#     353         The enclosing bounding box (in figure pixel coordinates).
#     354     """
# --> 355     bbox = self.get_window_extent(renderer)
#     356     if self.get_clip_on():
#     357         clip_box = self.get_clip_box()
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\patches.py:629, in Patch.get_window_extent(self, renderer)
#     628 def get_window_extent(self, renderer=None):
# --> 629     return self.get_path().get_extents(self.get_transform())
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\patches.py:278, in Patch.get_transform(self)
#     276 def get_transform(self):
#     277     """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 278     return self.get_patch_transform() + artist.Artist.get_transform(self)
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\patches.py:758, in Rectangle.get_patch_transform(self)
#     753 def get_patch_transform(self):
#     754     # Note: This cannot be called until after this has been added to
#     755     # an Axes, otherwise unit conversion will fail. This makes it very
#     756     # important to call the accessor method and not directly access the
#     757     # transformation member variable.
# --> 758     bbox = self.get_bbox()
#     759     return (transforms.BboxTransformTo(bbox)
#     760             + transforms.Affine2D().rotate_deg_around(
#     761                 bbox.x0, bbox.y0, self.angle))
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\patches.py:851, in Rectangle.get_bbox(self)
#     849 """Return the `.Bbox`."""
#     850 x0, y0, x1, y1 = self._convert_units()
# --> 851 return transforms.Bbox.from_extents(x0, y0, x1, y1)
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\transforms.py:839, in Bbox.from_extents(minpos, *args)
#     822 @staticmethod
#     823 def from_extents(*args, minpos=None):
#     824     """
#     825     Create a new Bbox from *left*, *bottom*, *right* and *top*.
#     826
#    (...)
#     837        scales where negative bounds result in floating point errors.
#     838     """
# --> 839     bbox = Bbox(np.reshape(args, (2, 2)))
#     840     if minpos is not None:
#     841         bbox._minpos[:] = minpos
#
# File ~\Python\anaconda3\envs\pythondata\lib\site-packages\matplotlib\transforms.py:785, in Bbox.__init__(self, points, **kwargs)
#     781 self._ignore = True
#     782 # it is helpful in some contexts to know if the bbox is a
#     783 # default or has been mutated; we store the orig points to
#     784 # support the mutated methods
# --> 785 self._points_orig = self._points.copy()
#
# KeyboardInterrupt:
